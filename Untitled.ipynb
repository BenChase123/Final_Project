# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity
import cartopy.crs as ccrs
import numpy as np
import scipy.stats as sts
from sqlalchemy import create_engine

# %%
#NBA_Games_Data path files

games_csv_path = "NBA_Games_Data/games.csv"
games_details_csv_path = "NBA_Games_Data/games_details.csv"
players_csv_path = "NBA_Games_Data/players.csv"
ranking_csv_path = "NBA_Games_Data/ranking.csv"
teams_csv_path = "NBA_Games_Data/teams.csv"

#march-machine-learning-mania-2017 path files

RegularSeasonCompactResults_csv_path = "march-machine-learning-mania-2017/RegularSeasonCompactResults.csv"
RegularSeasonDetailedResults_csv_path = "march-machine-learning-mania-2017/RegularSeasonDetailedResults.csv"
SampleSubmission_csv_path = "march-machine-learning-mania-2017/SampleSubmission.csv"
Seasons_csv_path = "march-machine-learning-mania-2017/Seasons.csv"
Teams_csv_path = "march-machine-learning-mania-2017/Teams.csv"
TourneyCompactResults_csv_path = "march-machine-learning-mania-2017/TourneyCompactResults.csv"
TourneyDetailedResults_csv_path = "march-machine-learning-mania-2017/TourneyDetailedResults.csv"

# %%
#NBA_Games_Data data frames

games_df = pd.read_csv(games_csv_path, delimiter = ',', lineterminator='\n')
games_details_df = pd.read_csv(games_details_csv_path, delimiter = ',', lineterminator='\n')
players_df = pd.read_csv(players_csv_path, delimiter = ',', lineterminator='\n')
ranking_df = pd.read_csv(ranking_csv_path, delimiter = ',', lineterminator='\n')
teams_df = pd.read_csv(teams_csv_path, delimiter = ',', lineterminator='\n')

#march-machine-learning-mania-2017 data frames

RegularSeasonCompactResults_df = pd.read_csv(RegularSeasonCompactResults_csv_path, delimiter = ',', lineterminator='\n')
RegularSeasonDetailedResults_df = pd.read_csv(RegularSeasonDetailedResults_csv_path, delimiter = ',', lineterminator='\n')
SampleSubmission_df = pd.read_csv(SampleSubmission_csv_path, delimiter = ',', lineterminator='\n')
Seasons_df = pd.read_csv(Seasons_csv_path, delimiter = ',', lineterminator='\n')
Teams_df = pd.read_csv(Teams_csv_path, delimiter = ',', lineterminator='\n')
TourneyCompactResults_df = pd.read_csv(TourneyCompactResults_csv_path, delimiter = ',', lineterminator='\n')
TourneyDetailedResults_df = pd.read_csv(TourneyDetailedResults_csv_path, delimiter = ',', lineterminator='\n')

# %%
ranking_df.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM  G  \
# 0  1610612747          0      12020    2020-12-21       West  L.A. Lakers  4
# 1  1610612762          0      12020    2020-12-21       West         Utah  3
# 2  1610612740          0      12020    2020-12-21       West  New Orleans  2
# 3  1610612745          0      12020    2020-12-21       West      Houston  4
# 4  1610612763          0      12020    2020-12-21       West      Memphis  4
#
#    W  L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  4  0   1.00         2-0         2-0           NaN
# 1  3  0   1.00         2-0         1-0           NaN
# 2  2  0   1.00         1-0         1-0           NaN
# 3  3  1   0.75         2-0         1-1           NaN
# 4  3  1   0.75         1-1         2-0           NaN

# %%
##Data Exploration

# %%
# #what is the win rate over the entire dataset for each team?

# # Total number of matches.
# n_matches = data.shape[0]

# # Calculate number of features. -1 because we are saving one as the target variable (win/lose/draw)
# n_features = data.shape[1] - 1

# # Calculate matches won by home team.
# n_homewins = len(data[data.FTR == 'H'])

# # Calculate win rate for home team.
# win_rate = (float(n_homewins) / (n_matches)) * 100

# %%
# df['DataFrame Column'] = df['DataFrame Column'].astype(str)
# df['DataFrame Column'] = df['DataFrame Column'].apply(str)
# d['Report Number'] = d['Report Number'].str[3:]

# %%
games_df
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2020-12-19  12000047            Final    1610612753       1610612766
# 1        2020-12-19  12000048            Final    1610612764       1610612765
# 2        2020-12-19  12000049            Final    1610612763       1610612737
# 3        2020-12-18  12000039            Final    1610612754       1610612755
# 4        2020-12-18  12000040            Final    1610612761       1610612748
# ...             ...       ...              ...           ...              ...
# 23515    2014-10-06  11400007            Final    1610612737       1610612740
# 23516    2014-10-06  11400004            Final    1610612741       1610612764
# 23517    2014-10-06  11400005            Final    1610612747       1610612743
# 23518    2014-10-05  11400002            Final    1610612761       1610612758
# 23519    2014-10-04  11400001            Final    1610612748       1610612740
#
# ...

# %%
ranking_df['SEASON_ID'] = ranking_df['SEASON_ID'].astype(str)
ranking_df['SEASON_ID'] = ranking_df['SEASON_ID'].str[1:]

# %%
ranking_df
# Out:
#            TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE  \
# 0       1610612747          0      12020    2020-12-21       West
# 1       1610612762          0      12020    2020-12-21       West
# 2       1610612740          0      12020    2020-12-21       West
# 3       1610612745          0      12020    2020-12-21       West
# 4       1610612763          0      12020    2020-12-21       West
# ...            ...        ...        ...           ...        ...
# 188378  1610612765          0      22013    2014-09-01       East
# 188379  1610612738          0      22013    2014-09-01       East
# 188380  1610612753          0      22013    2014-09-01       East
# 188381  1610612755          0      22013    2014-09-01       East
# 188382  1610612749          0      22013    2014-09-01       East
#
#                 TEAM   G   W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0        L.A. Lakers   4   4   0  1.000         2-0         2-0           NaN
# ...

# %%
len(ranking_df)
# Out:
# 188383

# %%
games_df['SEASON_ID'] = games_df['SEASON_ID'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SEASON_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-013c9a4ad9d4> in <module>
# ...

# %%
len(games_df)
# Out:
# 23520

# %%
new_df = merge_df.merge(games_df,ranking_df,how='left',left_on=,right_on)
